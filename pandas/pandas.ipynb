# %%
# 1 a b c
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("Syssel.csv")
arbetade = sum(df.iloc[1:12]["Befolkningen 16+ år efter sysselsättning, ålder, kön och år"])

inte = sum(df.iloc[13:24]["Befolkningen 16+ år efter sysselsättning, ålder, kön och år"])

print(f" Totalt: {arbetade} Personer")
print(f" Totalt: {inte} Personer")
labels = ["förvärvsarbetande" ,"Ej förvärvsarbetande"]
sizes = [arbetade , inte]
color = ["pink", "yellow"]
plt.figure(figsize=(7,3))

plt.pie(sizes , colors=color,labels=labels,autopct="%1.1f%%",shadow=True )
plt.title("Yes sir")


df.iloc[1:24]
# Out:
#  Totalt: 2446374 Personer
#  Totalt: 1021417 Personer
#                                        Befolkningen 16+ år efter sysselsättning, ålder, kön och år
# förvärvsarbetande    16-19 år män                                                  58826
#                               kvinnor                                              72847
#                      20-24 år män                                                 192696
#                               kvinnor                                             174074
#                      25-29 år män                                                 293352
#                               kvinnor                                             268587
#                      30-34 år män                                                 303019
#                               kvinnor                                             271975
#                      35-39 år män                                                 280522
# ...

# %%
#Uppgift 2 abc
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("Syssel.csv")
lista = df["Befolkningen 16+ år efter sysselsättning, ålder, kön och år"]

df.sort_values(by=["Befolkningen 16+ år efter sysselsättning, ålder, kön och år"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9ead19deb972> in <module>
#       6 lista = df["Befolkningen 16+ år efter sysselsättning, ålder, kön och år"]
#       7
# ----> 8 df.sort_values(by=[lista])
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
# ...
